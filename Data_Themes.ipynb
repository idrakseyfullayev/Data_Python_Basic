# %%
# !pip install jupyterthemes

# %%
# !jt -t onedork -fs 12 -cellw 95% -lineh 150

# %%
# ideal
# !jt -t onedork -f roboto -fs 11 -nf roboto -nfs 11 -cellw 96% -lineh 150 -T

# %%
# default
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\dell\.jupyter\custom &
# C:\Users\dell\AppData\Roaming\jupyter\nbextensions

# %%
# !jt -t onedork

# %%
# idela 2
# !jt -t gruvboxd -f roboto -fs 11 -nf roboto -nfs 11 -cellw 96% -lineh 150 -T

# %%
# ideal 3 en yaxhsisi
# !jt -t onedork -f roboto -fs 11 -nf roboto -nfs 11 -cellw 96% -lineh 150 -T -altout

# %%
# ideal 4 en yaxhsisi
# !jt -t onedork -f roboto -fs 11 -nf roboto -nfs 11 -cellw 96% -lineh 150 -T -altout -ofs 12

# %%
# ən ideal 5 ən yaxşısı budur
# !jt -t gruvboxd -f roboto -fs 11 -nf roboto -nfs 11 -cellw 90% -lineh 150 -T -altout -ofs 11

# %%
# ən ideal 5 ən yaxşısı budur son qərar
# !jt -t onedork -f roboto -fs 11 -nf roboto -nfs 11 -cellw 96% -lineh 150 -T -altout -ofs 11

# %%
# ən ideal 5 ən yaxşısı budur son qərar
#  Markdown font olçüsü
# !echo div.text_cell_render {{ font-size: 9pt; }} >> C:\\Users\\dell\\.jupyter\\custom\\custom.css
